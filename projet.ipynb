# %%
# Importation des librairies
import pandas as pd

# %%
# Chargements des datasets des données generales 
vacsi_tot_fra=pd.read_csv('general/vacsi-tot-fra-2023-07-13-15h50.csv',sep=';')
vacsi_tot_reg=pd.read_csv('general/vacsi-tot-reg-2023-07-13-15h50.csv',sep=';')
vacsi_tot_dep=pd.read_csv('general/vacsi-tot-dep-2023-07-13-15h50.csv',sep=';')

vacsi_fra=pd.read_csv('general/vacsi-fra-2023-07-13-15h50.csv',sep=';')
vacsi_reg=pd.read_csv('general/vacsi-reg-2023-07-13-15h50.csv',sep=';')
vacsi_dep=pd.read_csv('general/vacsi-dep-2023-07-13-15h50.csv',sep=';')
# Out:
# C:\Users\Bilel\AppData\Local\Temp\ipykernel_8836\3052643826.py:8: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   vacsi_dep=pd.read_csv('general/vacsi-dep-2023-07-13-15h50.csv',sep=';')

# %%
# Chargements des datasets des données selon le sexe et l'age 

vacsi_s_a_fra=pd.read_csv('sex.age/vacsi-s-a-fra-2023-07-13-15h51.csv',sep=';')
vacsi_s_a_reg=pd.read_csv('sex.age/vacsi-s-a-reg-2023-07-13-15h51.csv',sep=';')
vacsi_s_a_dep=pd.read_csv('sex.age/vacsi-s-a-dep-2023-07-13-15h51.csv',sep=';')
# Out:
# C:\Users\Bilel\AppData\Local\Temp\ipykernel_8836\2486280116.py:5: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   vacsi_s_a_dep=pd.read_csv('sex.age/vacsi-s-a-dep-2023-07-13-15h51.csv',sep=';')

# %%
# Chargements des datasets des données totale selon le sexe 

vacsi_tot_s_fra=pd.read_csv('sexe/vacsi-tot-s-fra-2023-07-13-15h51.csv',sep=';')
vacsi_tot_s_reg=pd.read_csv('sexe/vacsi-tot-s-reg-2023-07-13-15h51.csv',sep=';')
vacsi_tot_s_dep=pd.read_csv('sexe/vacsi-tot-s-dep-2023-07-13-15h51.csv',sep=';')

# Chargements des datasets des données  selon le sexe  par date d’injection 
vacsi_s_fra=pd.read_csv('sexe/vacsi-s-fra-2023-07-13-15h50.csv',sep=';')
vacsi_s_reg=pd.read_csv('sexe/vacsi-s-reg-2023-07-13-15h51.csv',sep=';')
vacsi_s_dep=pd.read_csv('sexe/vacsi-s-dep-2023-07-13-15h51.csv',sep=';')
# Out:
# C:\Users\Bilel\AppData\Local\Temp\ipykernel_8836\2293931401.py:10: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   vacsi_s_dep=pd.read_csv('sexe/vacsi-s-dep-2023-07-13-15h51.csv',sep=';')

# %%
# Chargements des datasets des données totale selon l'age 

vacsi_tot_a_fra=pd.read_csv('age/vacsi-tot-a-fra-2023-07-13-15h50.csv',sep=';')
vacsi_tot_a_reg=pd.read_csv('age/vacsi-tot-a-reg-2023-07-13-15h50.csv',sep=';')
vacsi_tot_a_dep=pd.read_csv('age/vacsi-tot-a-dep-2023-07-13-15h50.csv',sep=';')

# Chargements des datasets des données  selon l'age et par date d’injection 

vacsi_a_fra=pd.read_csv('age/vacsi-a-fra-2023-07-13-15h50.csv',sep=';')
vacsi_a_reg=pd.read_csv('age/vacsi-a-reg-2023-07-13-15h50.csv',sep=';')
vacsi_a_dep=pd.read_csv('age/vacsi-a-dep-2023-07-13-15h50.csv',sep=';')
# Out:
# C:\Users\Bilel\AppData\Local\Temp\ipykernel_8836\2261168761.py:11: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   vacsi_a_dep=pd.read_csv('age/vacsi-a-dep-2023-07-13-15h50.csv',sep=';')

# %%
# Chargements des datasets des données totale  par vaccin

vacsi_tot_v_fra=pd.read_csv('vaccin/vacsi-tot-v-fra-2023-07-13-15h51.csv',sep=';')
vacsi_tot_v_reg=pd.read_csv('vaccin/vacsi-tot-v-reg-2023-07-13-15h51.csv',sep=';')
vacsi_tot_v_dep=pd.read_csv('vaccin/vacsi-tot-v-dep-2023-07-13-15h51.csv',sep=';')

# Chargements des datasets des données par date d’injection et par vaccin
vacsi_v_fra=pd.read_csv('vaccin/vacsi-v-fra-2023-07-13-15h51.csv',sep=';')
vacsi_v_reg=pd.read_csv('vaccin/vacsi-v-reg-2023-07-13-15h51.csv',sep=';')
vacsi_v_dep=pd.read_csv('vaccin/vacsi-v-dep-2023-07-13-15h51.csv',sep=';')
# Out:
# C:\Users\Bilel\AppData\Local\Temp\ipykernel_8836\1301726416.py:10: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   vacsi_v_dep=pd.read_csv('vaccin/vacsi-v-dep-2023-07-13-15h51.csv',sep=';')

# %%
vacsi_s_a_dep=pd.read_csv('sex.age/vacsi-s-a-dep-2023-07-13-15h51.csv',sep=';')
